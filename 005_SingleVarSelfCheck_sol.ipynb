# %% [markdown]
# This is a (mostly) empty template that can be used for a little bit of a self check of the CH 1-4 stuff, or the basic examination of one varaible.
#
# This is useful becuase there's very little guidance, so you'll need to figure out what to do on your own. Looking forward, one of the primary reasons that we need to know this stuff for machine learning is something called Exploratory Data Analysis (EDA), which is usually the first step in doing machine learning stuff. We take whatever data we're using, load it up, and look through it to see if anything is wrong, weird, useful, or interersting. This helps us prepare our data for the ML work, to make things as accurate and reliable as possible. This little bit is kind of part 1 of EDA that you'll need to do later on.
#
# The first dataset is pretty simple. The second is slightly more complex.

# %% [markdown]
# Here's a few potentially useful things that you don't need to memorize:
# Get rid of any non-numbers: newDataFrame = oldDF[~np.isnan(oldDF)]
# Apply a function to everything in a dataframe (one with one column!):
#  (e.g. mult by 2.54): dataFrame.apply(lambda x: x*2.54)
#  (e.g. )

# %%
#Import Stuff
import thinkplot
import thinkstats2
import pandas as pd
import numpy as np

# %%
#Load the data
#filename is 'HeightWeight.csv"
df = pd.read_csv("HeightWeight.csv")
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
#Do basic exploration - range, min, max, std, mean...
#Ask yourself, does this match your understanding of reality?
df.describe(include="all")
# Out:
#         Gender      Height      Weight       Index
# count      500  500.000000  500.000000  500.000000
# unique       2         NaN         NaN         NaN
# top     Female         NaN         NaN         NaN
# freq       255         NaN         NaN         NaN
# mean       NaN  169.944000  106.000000    3.748000
# std        NaN   16.375261   32.382607    1.355053
# min        NaN  140.000000   50.000000    0.000000
# 25%        NaN  156.000000   80.000000    3.000000
# 50%        NaN  170.500000  106.000000    4.000000
# 75%        NaN  184.000000  136.000000    5.000000
# max        NaN  199.000000  160.000000    5.000000

# %%
#Graph it, can you make a histogram, PMF, CDF?
#When you look at it, does it make sense?
hist = thinkstats2.Hist(round(df["Weight"], -1), label="Weight")
pmf = thinkstats2.Pmf(round(df["Weight"], -1), label="Weight")
cdf = thinkstats2.Cdf(round(df["Weight"]), label="Weight")

# %%
thinkplot.PrePlot(3, cols=3)
thinkplot.Hist(hist)
thinkplot.SubPlot(2)
thinkplot.Pmf(pmf)
thinkplot.SubPlot(3)
thinkplot.Cdf(cdf)
thinkplot.Config(xlim=[40, 180])

# %%
#Split the data. Do the stats and graphs for each gender.
#Again, does it make sense? Match your understanding of reality?
df_man = df[df["Gender"] == "Male"]
df_fem = df[df["Gender"] == "Female"]

# %%
#Create a bunch of split hist/pmf/cdf
histm = thinkstats2.Hist(round(df_man["Weight"], -1), label="Men")
histf = thinkstats2.Hist(round(df_fem["Weight"], -1), label="Women")

pmfm = thinkstats2.Pmf(round(df_man["Weight"], -1), label="Men")
pmff = thinkstats2.Pmf(round(df_fem["Weight"], -1), label="Women")

cdfm = thinkstats2.Cdf(round(df_man["Weight"]), label="Men")
cdff = thinkstats2.Cdf(round(df_fem["Weight"]), label="Women")

# %%
thinkplot.PrePlot(3, cols=3)
thinkplot.Hist(histm, color="blue", align="right", width=4.5)
thinkplot.Hist(histf, color="red", align="left", width=4.5)
thinkplot.SubPlot(2)
thinkplot.Pmf(pmfm, color="blue")
thinkplot.Pmf(pmff, color="red")
thinkplot.SubPlot(3)
thinkplot.Cdf(cdfm, color="blue")
thinkplot.Cdf(cdff, color="red")
thinkplot.Config(xlim=[40, 180])

# %%
#In your exploration, did anythign stand out? Are there weird patterns? Outliers? Things that
#don't make sense? Errors? Incorrect values?
#(This dataset is pretty simple, so if you don't see anything crazy, that's normal)

#Weight of women seems to be slightly flatter (lower kurtosis - this term comes later)
#Overall it is more uniform, and less normal than I'd expect.

# %% [markdown]
# Repeat the basic process with this more complex data. For this, you might need to do more investigation/examination - particulary with things like errors, outliers, etc....
#
# This is kind of realistic - here's some data, is there anything we need to 'worry' about in using it? Does anything jump out as potentially interesting? Or possibly indicitive of something?
#
# If you consider WAGE as the varaible you care about - look for dasic descriptions, patterns, outliers or errors. Do things like POSITION or NATIONALITY indicate any differences in the WAGE?

# %%
#Filename is "fifa_eda.csv"
df2 = pd.read_csv("fifa_eda.csv")
df2.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0

# %%
#Generate some statistics
df2.describe(include="all")
# Out:
#                    ID          Name           Age Nationality       Overall  \
# count    18207.000000         18207  18207.000000       18207  18207.000000
# unique            NaN         17194           NaN         164           NaN
# top               NaN  J. Rodríguez           NaN     England           NaN
# freq              NaN            11           NaN        1662           NaN
# mean    214298.338606           NaN     25.122206         NaN     66.238699
# std      29965.244204           NaN      4.669943         NaN      6.908930
# min         16.000000           NaN     16.000000         NaN     46.000000
# 25%     200315.500000           NaN     21.000000         NaN     62.000000
# 50%     221759.000000           NaN     25.000000         NaN     66.000000
# 75%     236529.500000           NaN     28.000000         NaN     71.000000
# max     246620.000000           NaN     45.000000         NaN     94.000000
#
#            Potential             Club          Value          Wage  \
# count   18207.000000            17966   17955.000000  18207.000000
# unique           NaN              651            NaN           NaN
# top              NaN  Atlético Madrid            NaN           NaN
# freq             NaN               33            NaN           NaN
# mean       71.307299              NaN    2444.530214      9.731312
# std         6.136496              NaN    5626.715434     21.999290
# min        48.000000              NaN      10.000000      0.000000
# 25%        67.000000              NaN     325.000000      1.000000
# 50%        71.000000              NaN     700.000000      3.000000
# 75%        75.000000              NaN    2100.000000      9.000000
# max        95.000000              NaN  118500.000000    565.000000
#
#        Preferred Foot  International Reputation   Skill Moves Position  \
# count           18207              18159.000000  18159.000000    18207
# unique              2                       NaN           NaN       27
# top             Right                       NaN           NaN       ST
# freq            13996                       NaN           NaN     2154
# mean              NaN                  1.113222      2.361308      NaN
# std               NaN                  0.394031      0.756164      NaN
# min               NaN                  1.000000      1.000000      NaN
# 25%               NaN                  1.000000      2.000000      NaN
# 50%               NaN                  1.000000      2.000000      NaN
# 75%               NaN                  1.000000      3.000000      NaN
# max               NaN                  5.000000      5.000000      NaN
#
#               Joined Contract Valid Until        Height        Weight  \
# count   18207.000000                17918  18207.000000  18207.000000
# unique           NaN                   35           NaN           NaN
# top              NaN           2019-01-01           NaN           NaN
# freq             NaN                 4870           NaN           NaN
# mean     2016.420607                  NaN      5.946771    165.979129
# std         2.018194                  NaN      0.220514     15.572775
# min      1991.000000                  NaN      5.083333    110.000000
# 25%      2016.000000                  NaN      5.750000    154.000000
# 50%      2017.000000                  NaN      5.916667    165.000000
# 75%      2018.000000                  NaN      6.083333    176.000000
# max      2018.000000                  NaN      6.750000    243.000000
#
#         Release Clause
# count     18207.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean       4585.060971
# std       10630.414430
# min          13.000000
# 25%         570.000000
# 50%        1300.000000
# 75%        4585.060806
# max      228100.000000

# %%
df3 = df2[["Wage", "Position", "Nationality"]]
df3.describe(include="all")
# Out:
#                 Wage Position Nationality
# count   18207.000000    18207       18207
# unique           NaN       27         164
# top              NaN       ST     England
# freq             NaN     2154        1662
# mean        9.731312      NaN         NaN
# std        21.999290      NaN         NaN
# min         0.000000      NaN         NaN
# 25%         1.000000      NaN         NaN
# 50%         3.000000      NaN         NaN
# 75%         9.000000      NaN         NaN
# max       565.000000      NaN         NaN

# %% [markdown]
# One thing to note right here - we have a real outlier! Look at the largest wage.
# Is this an error? Is someone just Bezos-level right? We need domain knowledge - i.e. I'm going to look up more info and Google
#
# As well, some people have a wage of 0.

# %%
#Look up the rich person
df2[df2["Wage"] == 565]
# Out:
#        ID      Name  Age Nationality  Overall  Potential          Club  \
# 0  158023  L. Messi   31   Argentina       94         94  FC Barcelona
#
#       Value   Wage Preferred Foot  International Reputation  Skill Moves  \
# 0  110500.0  565.0           Left                       5.0          4.0
#
#   Position  Joined Contract Valid Until    Height  Weight  Release Clause
# 0       RF    2004           2021-01-01  5.583333   159.0        226500.0

# %% [markdown]
# I don't know much about the details of soccer, but I do know Messi is a crazy huge star. I'm going to Google "Messi Wage" and see what I find.
# One of the first hits was: https://www.cbssports.com/soccer/news/lionel-messi-barcelona-contract-details-674-million-earnings-leaked-by-spanish-paper-in-bombshell-report/
# It appears this is real.
#
# Should we remove it? Depends on out exact intent... If we are looking at how much soccar players normally earn, filtering out people who are such massive outliers
# may make sense. This is where we need to understand what we are doing this for, in reality - not stats.
# We are basically doing this as an exercise, so we can arbitrarily pick. I'm going to say that if there is a 'stream' of big salaries leading up to Messi, we'll leave it in.
# If he's way out in front with a massive
#
# The 0 wages are similar. Are they players who are between contracts? Players who didn't make the cut? We need to know what this means in reality to make a real decision.
# Since the wage values are in the hundreds, and based off of what I read in teh above article, I can surmise that these contracts are likely less than one million, since the wage
# values are measured in millions. They stay!

# %%
#Look at the top 25 salaries
df2 = df2.sort_values(by=["Wage"], ascending=False)
df2.tail(25)
# Out:
#            ID            Name  Age     Nationality  Overall  Potential  \
# 14215  240738     R. Muhammed   24          France       61         64
# 14190  224345     A. Kartalis   23          Greece       61         65
# 14427  209065       M. Moënza   24          Sweden       61         66
# 14447  209842      Christovao   25          Angola       61         64
# 14213  231522      A. Stadler   30   United States       61         61
# 14186  242263     M. Amundsen   20         Denmark       61         74
# 14211  176737   B. Ziegenbein   32         Germany       61         61
# 6392   201163     M. Frydrych   28  Czech Republic       69         69
# 14454  242611  K. Kristinsson   19         Iceland       61         74
# 6393   224715      N. Chernov   22          Russia       69         79
# 14354  243602      S. Mbakata   20          France       61         70
# 14442  224942      R. Alvarez   19           Chile       61         79
# 5493   209874     B. Khuzwayo   28    South Africa       70         72
# 14441  242093       E. Omondi   23           Kenya       61         66
# 14219  227173      M. Payares   23        Colombia       61         71
# 11051  177679      D. Vržogić   28         Germany       64         64
# 14189  240728      D. Tchamba   19        Cameroon       61         74
# 6398   159436       R. Zapata   39        Colombia       69         69
# 6568   244467        O. Kolář   23  Czech Republic       69         76
# 11930  240352      J. Riquett   28        Colombia       64         66
# 6556   214258      M. Riquero   35         Uruguay       69         69
# 14469  236216       E. Mensah   20           Ghana       61         72
# 11924  238815      L. Riveros   19        Paraguay       64         73
# 6570   229108        J. Pérez   29        Colombia       69         69
# 17861  245726   F. Bustamante   19       Argentina       52         66
#
#                                Club   Value  Wage Preferred Foot  \
# 14215               Sarpsborg 08 FF   325.0   1.0          Right
# 14190                   FSV Zwickau   270.0   1.0           Left
# 14427                    Dalkurd FF   280.0   1.0           Left
# 14447            Zagłębie Sosnowiec   325.0   1.0          Right
# 14213                    Dalkurd FF   240.0   1.0          Right
# 14186        Eintracht Braunschweig   425.0   1.0           Left
# 14211            FC Energie Cottbus   200.0   1.0          Right
# 6392                SK Slavia Praha   825.0   1.0          Right
# 14454                     Willem II   475.0   1.0          Right
# 6393                PFC CSKA Moscow  1500.0   1.0          Right
# 14354        FC Sochaux-Montbéliard   325.0   1.0          Right
# 14442                     Colo-Colo   550.0   1.0           Left
# 5493                Orlando Pirates  1500.0   1.0          Right
# 14441             IF Brommapojkarna   325.0   1.0          Right
# 14219               Deportivo Pasto   350.0   1.0          Right
# 11051                     SV Meppen   350.0   1.0           Left
# 14189          RC Strasbourg Alsace   425.0   1.0           Left
# 6398         Independiente Santa Fe    70.0   1.0          Right
# 6568                SK Slavia Praha  1100.0   1.0          Right
# 11930                    La Equidad   425.0   1.0          Right
# 6556           Club Deportes Temuco   250.0   1.0          Right
# 14469                  HJK Helsinki   425.0   1.0           Left
# 11924  CD Universidad de Concepción   675.0   1.0          Right
# 6570           Atlético Bucaramanga  1000.0   1.0          Right
# 17861           Club Atlético Tigre   110.0   1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 14215                       1.0          2.0       RS    2017
# 14190                       1.0          3.0       LB    2018
# 14427                       1.0          2.0       LB    2017
# 14447                       1.0          3.0       RM    2017
# 14213                       1.0          2.0       ST    2017
# 14186                       1.0          3.0       LB    2016
# 14211                       1.0          3.0       RM    2016
# 6392                        1.0          2.0       RB    2015
# 14454                       1.0          3.0       LW    2016
# 6393                        1.0          2.0       CB    2013
# 14354                       1.0          2.0       RB    2018
# 14442                       1.0          3.0       LM    2016
# 5493                        1.0          1.0       GK    2018
# 14441                       1.0          2.0       RW    2018
# 14219                       1.0          2.0       CB    2018
# 11051                       1.0          3.0       LB    2016
# 14189                       1.0          2.0       CB    2017
# 6398                        1.0          1.0       GK    2014
# 6568                        1.0          1.0       GK    2018
# 11930                       1.0          2.0      LCB    2017
# 6556                        1.0          2.0      RDM    2017
# 14469                       1.0          2.0       RW    2017
# 11924                       1.0          3.0       ST    2017
# 6570                        1.0          3.0       LM    2016
# 17861                       1.0          2.0       RM    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 14215           2020-01-01  6.000000   181.0      431.000000
# 14190           2019-01-01  5.833333   146.0      412.000000
# 14427           2019-01-01  5.916667   165.0      371.000000
# 14447           2019-01-01  6.083333   187.0      463.000000
# 14213           2018-01-01  5.833333   157.0      300.000000
# 14186           2019-06-30  5.833333   179.0     4585.060806
# 14211           2019-01-01  5.750000   159.0      290.000000
# 6392            2019-01-01  6.166667   183.0     1800.000000
# 14454           2019-01-01  6.250000   157.0      986.000000
# 6393            2019-01-01  6.166667   174.0     3500.000000
# 14354           2021-01-01  5.833333   159.0      634.000000
# 14442           2019-01-01  5.750000   152.0     1100.000000
# 5493            2021-01-01  6.250000   165.0     3300.000000
# 14441           2021-01-01  6.083333   165.0      431.000000
# 14219           2023-01-01  6.000000   159.0      543.000000
# 11051           2020-01-01  5.916667   150.0      508.000000
# 14189           2021-01-01  6.000000   174.0     1100.000000
# 6398            2022-01-01  6.000000   187.0       98.000000
# 6568            2022-01-01  6.333333   179.0     2600.000000
# 11930           2018-01-01  6.000000   176.0      606.000000
# 6556            2018-01-01  5.833333   168.0      338.000000
# 14469           2019-01-01  5.416667   137.0      999.000000
# 11924           2020-01-01  5.833333   161.0     1100.000000
# 6570            2020-01-01  5.750000   148.0     1400.000000
# 17861           2021-01-01  5.500000   143.0      234.000000

# %% [markdown]
# There are a lot of big contracts, Messi shall live on in our data.

# %%
#Graph the wage on its own.
#Create objects for graphing
hist2 = thinkstats2.Hist(round(df3["Wage"], -1))
pmf2 = thinkstats2.Pmf(round(df3["Wage"], -1))
cdf2 = thinkstats2.Cdf(df3["Wage"])

# %%
#Create graphs
thinkplot.PrePlot(3, cols=3)
thinkplot.Hist(hist2)
thinkplot.SubPlot(2)
thinkplot.Pmf(pmf2)
thinkplot.SubPlot(3)
thinkplot.Cdf(cdf2)
thinkplot.Config()

# %% [markdown]
# Looks very clustered at the start. Maybe a pareto dist?
#
# I'm going to zoom in on the start, with the lower salaries before going forward.

# %%
#Take a quick look at the lower salaries. 
thinkplot.PrePlot(1)
dftmp = df3[df3["Wage"]<20]
thinkplot.Pmf(thinkstats2.Pmf(dftmp["Wage"]))
thinkplot.Config()

# %% [markdown]
# We were asked to look at position and nationality, so we can examine that and see if that impacts wages

# %%
#This part isn't super straightforward, since both nationality and position have lots of options
#Realistically, this requires some open ended thought, and probably a little research.
#My first idea is to calculate the mean (and maybe other stats) for each position or each nationality
#I need to figure out how to take all goalies, calculate metrics, then take all defenders, calculate metrics, etc....
#Or something along those lines, there are a lot of ways to address a querstion like this...

#We could write a loop, but that is more work.
#The groupby function does it for us, we say how we want it grouped, and add the calculation for each group. 
#We can do this once for each metric we care about, then put the results into a new dataframe.

posWages = df3.groupby(by="Position").mean()
posStd = df3.groupby(by="Position").std()
posMed = df3.groupby(by="Position").median()

wages = pd.DataFrame(posWages)
wages = wages.rename(columns={"Wage":"Mean"})
wages["Std"] = posStd
wages["Median"] = posMed
wages.sort_values("Mean", ascending=False)
# Out:
#                Mean         Std  Median
# Position
# RF        52.687500  140.297645    11.5
# LF        44.666667   96.328802     9.0
# LAM       26.142857   66.644044    10.0
# RAM       19.095238   30.898066    12.0
# LS        15.260870   26.839139     6.0
# RW        14.432432   32.296006     4.0
# RCM       14.404092   34.726335     4.0
# RS        14.379310   34.736761     6.0
# LCM       14.131646   30.169872     5.0
# LW        13.068241   34.045257     3.0
# RCB       12.688822   27.327672     4.0
# RDM       12.149194   20.167666     5.5
# LDM       11.860082   25.984996     4.0
# LCB       11.498457   21.126468     4.0
# CAM       10.218978   21.270404     3.0
# CF        10.216216   15.668894     3.0
# ST         9.928969   22.493041     3.0
# LM         9.656621   18.619074     4.0
# RM         9.515528   18.173759     3.0
# CDM        9.315401   21.245353     3.0
# LWB        9.076923   12.424075     3.0
# RB         8.604183   16.732940     3.0
# RWB        8.597701   14.466047     2.0
# LB         8.467930   18.040104     3.0
# CM         8.334767   17.939814     2.0
# CB         7.700393   16.384465     2.0
# GK         6.797237   16.712741     2.0

# %% [markdown]
# I googled soccer positions and got: https://yoursoccerhome.com/soccer-position-abbreviations-what-do-they-all-mean/
#
# I can reasonably conclude that it looks like midfielders and forwards make the most money. More specifically the highest paid players are forwards - this is largely from the higher median vs mean.

# %%
#Same deal for nationality. 
natWages = df3.groupby(by="Nationality").mean()
natStd = df3.groupby(by="Nationality").std()
natMed = df3.groupby(by="Nationality").median()
natCnt = df3.groupby(by="Nationality").size()

wages2 = pd.DataFrame(natWages)
wages2 = wages2.rename(columns={"Wage":"Mean"})
wages2["Std"] = natStd
wages2["Median"] = natMed
wages2["Count"] = natCnt

wages2 = wages2[wages2["Count"]>10]

wages2 = wages2.sort_values("Mean", ascending=False)
wages2.head(20)
# Out:
#                          Mean        Std  Median  Count
# Nationality
# Gabon               26.933333  67.187867     5.0     15
# Croatia             21.682540  50.702686     5.0    126
# Belgium             18.480769  43.716395     6.0    260
# Algeria             18.083333  29.748261     7.0     60
# Brazil              17.778718  31.885398    10.0    827
# Uruguay             17.006711  43.226227     7.0    149
# Egypt               16.870968  46.768039     3.0     31
# Spain               16.322761  33.260569     6.0   1072
# Togo                16.000000  12.613124    13.5     12
# Israel              15.857143  13.143335    14.5     14
# Bosnia Herzegovina  14.868852  29.780013     5.0     61
# Morocco             14.847059  21.393983     8.0     85
# Senegal             14.361538  24.889525     7.0    130
# Portugal            14.310559  30.146731     6.0    322
# France              14.053611  26.589376     4.0    914
# DR Congo            13.769231  14.594675     8.0     52
# Costa Rica          13.566667  35.226052     4.0     30
# Italy               13.478632  23.222093     3.0    702
# Serbia              13.404762  20.307310     6.0    126
# Montenegro          13.086957  21.358228     4.0     23

# %%
wages2 = wages2.sort_values("Median", ascending=False)
wages2.head(20)
# Out:
#                   Mean        Std  Median  Count
# Nationality
# Israel       15.857143  13.143335    14.5     14
# Togo         16.000000  12.613124    13.5     12
# Brazil       17.778718  31.885398    10.0    827
# Cape Verde   11.526316  14.131794     8.0     19
# DR Congo     13.769231  14.594675     8.0     52
# Mali         10.674419   9.694674     8.0     43
# Morocco      14.847059  21.393983     8.0     85
# Honduras      7.500000   6.613118     7.0     16
# Algeria      18.083333  29.748261     7.0     60
# Uruguay      17.006711  43.226227     7.0    149
# Senegal      14.361538  24.889525     7.0    130
# Iran         11.294118  14.207237     6.0     17
# Argentina    11.502668  27.199489     6.0    937
# Serbia       13.404762  20.307310     6.0    126
# Gambia        8.133333   8.576268     6.0     15
# Portugal     14.310559  30.146731     6.0    322
# Spain        16.322761  33.260569     6.0   1072
# Belgium      18.480769  43.716395     6.0    260
# Tunisia       9.218750   9.195842     5.5     32
# Gabon        26.933333  67.187867     5.0     15

# %% [markdown]
# The nationality thing is a little harder to draw solid inferences from. Countries that have a low number of players are highly variable - one or two really highly paid stars can shift the metrics - e.g. look at the std for Gabon. (More Gabon below)
#
# We'd probably need to cut it down even futher to countries that have a large number of players to get an actual trend. Doing that makes things look more like we may expect - big time soccer countries have lots of highly paid players.
#
# One thing to note here is that it appears that the wealth is, comparatively, spread all over the globe. Small and less developed countries seem to have more big ballers than we may initially expect.

# %%
#Look at Gabon for an example of the wide varaibility of wages. 
df2[df2["Nationality"]=="Gabon"].head(15)
# Out:
#            ID                   Name  Age Nationality  Overall  Potential  \
# 33     188567          P. Aubameyang   29       Gabon       88         88
# 793    212811              M. Lemina   24       Gabon       78         83
# 2293   188270        B. Ecuélé Manga   29       Gabon       74         74
# 3743   205998         A. Biyogo Poko   25       Gabon       72         76
# 3703   225951             D. Bouanga   23       Gabon       72         77
# 7455   202708               L. Palun   29       Gabon       68         68
# 3942   213498  S. Martinsson Ngouali   26       Gabon       72         74
# 13187  239910           A. Boupendza   21       Gabon       62         72
# 6620   212483              J. Obiang   24       Gabon       68         70
# 7765   199963          M. Tandjigora   28       Gabon       67         67
# 13700  244923      J. Branger-Engone   24       Gabon       62         65
# 1795   213353               K. Kanga   27       Gabon       75         75
# 16187  245454               W. Ebane   26       Gabon       58         59
# 10082  175141               D. Ovono   35       Gabon       65         65
# 14309  244099     L. Ameka Autchanga   21       Gabon       61         71
#
#                                  Club    Value   Wage Preferred Foot  \
# 33                            Arsenal  59000.0  265.0          Right
# 793                       Southampton  13500.0   44.0          Right
# 2293                     Cardiff City   4400.0   37.0          Right
# 3743                       Göztepe SK   3900.0   17.0          Right
# 3703                  Nîmes Olympique   4200.0   12.0          Right
# 7455                KSV Cercle Brugge    675.0    6.0          Right
# 3942                      Hammarby IF   3700.0    5.0          Right
# 13187                     GFC Ajaccio    500.0    5.0          Right
# 6620                     ESTAC Troyes    900.0    3.0           Left
# 7765                    Os Belenenses    625.0    3.0          Right
# 13700                 Oldham Athletic    375.0    3.0           Left
# 1795                     Sparta Praha   7000.0    1.0          Right
# 16187                      FC Lorient    120.0    1.0           Left
# 10082                        Paris FC    130.0    1.0          Right
# 14309  Chamois Niortais Football Club    400.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 33                          3.0          4.0       LM    2018
# 793                         2.0          3.0      LCM    2017
# 2293                        1.0          2.0       RB    2014
# 3743                        1.0          3.0      RDM    2018
# 3703                        1.0          3.0       LM    2018
# 7455                        1.0          2.0       RB    2017
# 3942                        1.0          3.0      LCM    2017
# 13187                       1.0          2.0       ST    2016
# 6620                        1.0          3.0       LB    2016
# 7765                        1.0          2.0      CDM    2017
# 13700                       1.0          4.0       RM    2018
# 1795                        1.0          4.0      RCM    2018
# 16187                       1.0          2.0       LB    2018
# 10082                       1.0          1.0       GK    2017
# 14309                       1.0          3.0       RM    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 33              2021-01-01  6.166667   176.0   112100.000000
# 793             2022-01-01  6.000000   187.0    26700.000000
# 2293            2019-01-01  6.083333   168.0     8700.000000
# 3743            2021-01-01  5.666667   159.0     8200.000000
# 3703            2021-01-01  5.916667   157.0     8600.000000
# 7455            2019-01-01  5.833333   170.0      979.000000
# 3942            2019-01-01  5.750000   165.0     4900.000000
# 13187           2019-06-30  5.916667   174.0     4585.060806
# 6620            2019-01-01  5.583333   141.0     1700.000000
# 7765            2021-01-01  5.666667   150.0     1300.000000
# 13700           2019-01-01  6.000000   163.0      684.000000
# 1795            2020-01-01  5.500000   148.0    15400.000000
# 16187           2019-01-01  5.916667   176.0      219.000000
# 10082           2023-01-01  6.083333   190.0      228.000000
# 14309           2021-01-01  5.750000   150.0      780.000000

# %%
wages2 = wages2[wages2["Count"]>200]

wages2 = wages2.sort_values("Mean", ascending=False)
wages2.head(20)
# Out:
#                    Mean        Std  Median  Count
# Nationality
# Belgium       18.480769  43.716395     6.0    260
# Brazil        17.778718  31.885398    10.0    827
# Spain         16.322761  33.260569     6.0   1072
# Portugal      14.310559  30.146731     6.0    322
# France        14.053611  26.589376     4.0    914
# Italy         13.478632  23.222093     3.0    702
# Argentina     11.502668  27.199489     6.0    937
# Turkey        10.442244  15.201161     5.0    303
# Switzerland   10.154545  17.010170     3.0    220
# Netherlands   10.035320  17.827308     4.0    453
# England        9.943442  19.169711     3.0   1662
# Germany        9.639399  22.121375     3.0   1198
# Mexico         8.825137  10.683339     5.0    366
# Scotland       7.975524  12.681639     3.0    286
# Austria        7.667785  13.110269     3.0    298
# Denmark        6.913690  15.223950     3.0    336
# Colombia       5.415858  17.715294     1.0    618
# Chile          5.176471  16.697829     1.0    391
# Poland         5.131429  15.719055     1.0    350
# Saudi Arabia   5.117647   5.010695     3.0    340
